# %%
import pandas as pd 
import requests
import json

# %%
token = 'b568f5763e0bc8521a0742a7d7f289af85c4f89d'

# %% [markdown]
# There's no main repo, so I choose lab-numpy for the exercise.

# %%
url = 'https://api.github.com/repos/ta-data-bcn/lab-numpy/issues?state=open'

url2 = 'https://api.github.com/repos/ta-data-bcn/lab-numpy/forks'
    
response = requests.get(url2).json()

# %%
response
# Out:
# [{'id': 175785038,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzU3ODUwMzg=',
#   'name': 'lab-numpy',
#   'full_name': 'adrientalbot/lab-numpy',
#   'private': False,
#   'owner': {'login': 'adrientalbot',
#    'id': 47277856,
#    'node_id': 'MDQ6VXNlcjQ3Mjc3ODU2',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/47277856?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adrientalbot',
#    'html_url': 'https://github.com/adrientalbot',
#    'followers_url': 'https://api.github.com/users/adrientalbot/followers',
#    'following_url': 'https://api.github.com/users/adrientalbot/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/adrientalbot/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/adrientalbot/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/adrientalbot/subscriptions',
#    'organizations_url': 'https://api.github.com/users/adrientalbot/orgs',
#    'repos_url': 'https://api.github.com/users/adrientalbot/repos',
#    'events_url': 'https://api.github.com/users/adrientalbot/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/adrientalbot/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/adrientalbot/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/adrientalbot/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/adrientalbot/lab-numpy/deployments',
#   'created_at': '2019-03-15T09:03:11Z',
#   'updated_at': '2019-03-15T09:03:15Z',
#   'pushed_at': '2019-03-05T18:20:16Z',
#   'git_url': 'git://github.com/adrientalbot/lab-numpy.git',
#   'ssh_url': 'git@github.com:adrientalbot/lab-numpy.git',
#   'clone_url': 'https://github.com/adrientalbot/lab-numpy.git',
#   'svn_url': 'https://github.com/adrientalbot/lab-numpy',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173802684,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzM4MDI2ODQ=',
#   'name': 'lab-numpy',
#   'full_name': 'NachoMartinezJ/lab-numpy',
#   'private': False,
#   'owner': {'login': 'NachoMartinezJ',
#    'id': 27884808,
#    'node_id': 'MDQ6VXNlcjI3ODg0ODA4',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/27884808?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NachoMartinezJ',
#    'html_url': 'https://github.com/NachoMartinezJ',
#    'followers_url': 'https://api.github.com/users/NachoMartinezJ/followers',
#    'following_url': 'https://api.github.com/users/NachoMartinezJ/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NachoMartinezJ/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NachoMartinezJ/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NachoMartinezJ/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NachoMartinezJ/orgs',
#    'repos_url': 'https://api.github.com/users/NachoMartinezJ/repos',
#    'events_url': 'https://api.github.com/users/NachoMartinezJ/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NachoMartinezJ/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/NachoMartinezJ/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/NachoMartinezJ/lab-numpy/deployments',
#   'created_at': '2019-03-04T18:54:12Z',
#   'updated_at': '2019-03-04T18:54:14Z',
#   'pushed_at': '2019-03-04T17:41:36Z',
#   'git_url': 'git://github.com/NachoMartinezJ/lab-numpy.git',
#   'ssh_url': 'git@github.com:NachoMartinezJ/lab-numpy.git',
#   'clone_url': 'https://github.com/NachoMartinezJ/lab-numpy.git',
#   'svn_url': 'https://github.com/NachoMartinezJ/lab-numpy',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173776807,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzM3NzY4MDc=',
#   'name': 'lab-numpy',
#   'full_name': 'alvarofc/lab-numpy',
#   'private': False,
#   'owner': {'login': 'alvarofc',
#    'id': 12977096,
#    'node_id': 'MDQ6VXNlcjEyOTc3MDk2',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/12977096?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alvarofc',
#    'html_url': 'https://github.com/alvarofc',
#    'followers_url': 'https://api.github.com/users/alvarofc/followers',
#    'following_url': 'https://api.github.com/users/alvarofc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alvarofc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alvarofc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alvarofc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alvarofc/orgs',
#    'repos_url': 'https://api.github.com/users/alvarofc/repos',
#    'events_url': 'https://api.github.com/users/alvarofc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alvarofc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/alvarofc/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/alvarofc/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/alvarofc/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/alvarofc/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/alvarofc/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/alvarofc/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/alvarofc/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/alvarofc/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/alvarofc/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/alvarofc/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/alvarofc/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/alvarofc/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/alvarofc/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/alvarofc/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/alvarofc/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/alvarofc/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/alvarofc/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/alvarofc/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/alvarofc/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/alvarofc/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/alvarofc/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/alvarofc/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/alvarofc/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/alvarofc/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/alvarofc/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/alvarofc/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/alvarofc/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/alvarofc/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/alvarofc/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/alvarofc/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/alvarofc/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/alvarofc/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/alvarofc/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/alvarofc/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/alvarofc/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/alvarofc/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/alvarofc/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/alvarofc/lab-numpy/deployments',
#   'created_at': '2019-03-04T16:03:46Z',
#   'updated_at': '2019-03-04T16:03:48Z',
#   'pushed_at': '2019-03-02T12:02:33Z',
#   'git_url': 'git://github.com/alvarofc/lab-numpy.git',
#   'ssh_url': 'git@github.com:alvarofc/lab-numpy.git',
#   'clone_url': 'https://github.com/alvarofc/lab-numpy.git',
#   'svn_url': 'https://github.com/alvarofc/lab-numpy',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173314542,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMzMTQ1NDI=',
#   'name': 'lab-numpy',
#   'full_name': 'chunsang0126/lab-numpy',
#   'private': False,
#   'owner': {'login': 'chunsang0126',
#    'id': 47787802,
#    'node_id': 'MDQ6VXNlcjQ3Nzg3ODAy',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/47787802?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chunsang0126',
#    'html_url': 'https://github.com/chunsang0126',
#    'followers_url': 'https://api.github.com/users/chunsang0126/followers',
#    'following_url': 'https://api.github.com/users/chunsang0126/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chunsang0126/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chunsang0126/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chunsang0126/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chunsang0126/orgs',
#    'repos_url': 'https://api.github.com/users/chunsang0126/repos',
#    'events_url': 'https://api.github.com/users/chunsang0126/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chunsang0126/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/chunsang0126/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/chunsang0126/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/chunsang0126/lab-numpy/deployments',
#   'created_at': '2019-03-01T14:22:00Z',
#   'updated_at': '2019-03-05T18:17:05Z',
#   'pushed_at': '2019-03-05T18:17:03Z',
#   'git_url': 'git://github.com/chunsang0126/lab-numpy.git',
#   'ssh_url': 'git@github.com:chunsang0126/lab-numpy.git',
#   'clone_url': 'https://github.com/chunsang0126/lab-numpy.git',
#   'svn_url': 'https://github.com/chunsang0126/lab-numpy',
#   'homepage': None,
#   'size': 8,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173313979,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMzMTM5Nzk=',
#   'name': 'lab-numpy',
#   'full_name': 'adriaferrer/lab-numpy',
#   'private': False,
#   'owner': {'login': 'adriaferrer',
#    'id': 46265200,
#    'node_id': 'MDQ6VXNlcjQ2MjY1MjAw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/46265200?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adriaferrer',
#    'html_url': 'https://github.com/adriaferrer',
#    'followers_url': 'https://api.github.com/users/adriaferrer/followers',
#    'following_url': 'https://api.github.com/users/adriaferrer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/adriaferrer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/adriaferrer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/adriaferrer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/adriaferrer/orgs',
#    'repos_url': 'https://api.github.com/users/adriaferrer/repos',
#    'events_url': 'https://api.github.com/users/adriaferrer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/adriaferrer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/adriaferrer/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/adriaferrer/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/adriaferrer/lab-numpy/deployments',
#   'created_at': '2019-03-01T14:18:38Z',
#   'updated_at': '2019-03-16T13:18:08Z',
#   'pushed_at': '2019-03-16T13:18:06Z',
#   'git_url': 'git://github.com/adriaferrer/lab-numpy.git',
#   'ssh_url': 'git@github.com:adriaferrer/lab-numpy.git',
#   'clone_url': 'https://github.com/adriaferrer/lab-numpy.git',
#   'svn_url': 'https://github.com/adriaferrer/lab-numpy',
#   'homepage': None,
#   'size': 11,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173298734,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyOTg3MzQ=',
#   'name': 'lab-numpy',
#   'full_name': 'jonathan9879/lab-numpy',
#   'private': False,
#   'owner': {'login': 'jonathan9879',
#    'id': 19253919,
#    'node_id': 'MDQ6VXNlcjE5MjUzOTE5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/19253919?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonathan9879',
#    'html_url': 'https://github.com/jonathan9879',
#    'followers_url': 'https://api.github.com/users/jonathan9879/followers',
#    'following_url': 'https://api.github.com/users/jonathan9879/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonathan9879/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonathan9879/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonathan9879/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonathan9879/orgs',
#    'repos_url': 'https://api.github.com/users/jonathan9879/repos',
#    'events_url': 'https://api.github.com/users/jonathan9879/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonathan9879/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/jonathan9879/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/jonathan9879/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/jonathan9879/lab-numpy/deployments',
#   'created_at': '2019-03-01T12:31:39Z',
#   'updated_at': '2019-03-01T14:33:42Z',
#   'pushed_at': '2019-03-01T14:33:40Z',
#   'git_url': 'git://github.com/jonathan9879/lab-numpy.git',
#   'ssh_url': 'git@github.com:jonathan9879/lab-numpy.git',
#   'clone_url': 'https://github.com/jonathan9879/lab-numpy.git',
#   'svn_url': 'https://github.com/jonathan9879/lab-numpy',
#   'homepage': None,
#   'size': 8,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173298588,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyOTg1ODg=',
#   'name': 'lab-numpy',
#   'full_name': 'dvsun/lab-numpy',
#   'private': False,
#   'owner': {'login': 'dvsun',
#    'id': 47750143,
#    'node_id': 'MDQ6VXNlcjQ3NzUwMTQz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/47750143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dvsun',
#    'html_url': 'https://github.com/dvsun',
#    'followers_url': 'https://api.github.com/users/dvsun/followers',
#    'following_url': 'https://api.github.com/users/dvsun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dvsun/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dvsun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dvsun/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dvsun/orgs',
#    'repos_url': 'https://api.github.com/users/dvsun/repos',
#    'events_url': 'https://api.github.com/users/dvsun/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dvsun/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/dvsun/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/dvsun/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/dvsun/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/dvsun/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/dvsun/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/dvsun/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/dvsun/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/dvsun/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/dvsun/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/dvsun/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/dvsun/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/dvsun/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/dvsun/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dvsun/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dvsun/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/dvsun/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/dvsun/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/dvsun/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/dvsun/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/dvsun/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/dvsun/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dvsun/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/dvsun/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/dvsun/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/dvsun/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/dvsun/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/dvsun/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/dvsun/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/dvsun/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/dvsun/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/dvsun/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/dvsun/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/dvsun/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/dvsun/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/dvsun/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/dvsun/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/dvsun/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/dvsun/lab-numpy/deployments',
#   'created_at': '2019-03-01T12:30:19Z',
#   'updated_at': '2019-03-04T17:41:37Z',
#   'pushed_at': '2019-03-04T17:41:35Z',
#   'git_url': 'git://github.com/dvsun/lab-numpy.git',
#   'ssh_url': 'git@github.com:dvsun/lab-numpy.git',
#   'clone_url': 'https://github.com/dvsun/lab-numpy.git',
#   'svn_url': 'https://github.com/dvsun/lab-numpy',
#   'homepage': None,
#   'size': 12,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173293985,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyOTM5ODU=',
#   'name': 'lab-numpy',
#   'full_name': 'annaviper/lab-numpy',
#   'private': False,
#   'owner': {'login': 'annaviper',
#    'id': 17914293,
#    'node_id': 'MDQ6VXNlcjE3OTE0Mjkz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/17914293?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/annaviper',
#    'html_url': 'https://github.com/annaviper',
#    'followers_url': 'https://api.github.com/users/annaviper/followers',
#    'following_url': 'https://api.github.com/users/annaviper/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/annaviper/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/annaviper/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/annaviper/subscriptions',
#    'organizations_url': 'https://api.github.com/users/annaviper/orgs',
#    'repos_url': 'https://api.github.com/users/annaviper/repos',
#    'events_url': 'https://api.github.com/users/annaviper/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/annaviper/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/annaviper/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/annaviper/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/annaviper/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/annaviper/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/annaviper/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/annaviper/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/annaviper/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/annaviper/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/annaviper/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/annaviper/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/annaviper/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/annaviper/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/annaviper/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/annaviper/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/annaviper/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/annaviper/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/annaviper/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/annaviper/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/annaviper/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/annaviper/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/annaviper/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/annaviper/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/annaviper/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/annaviper/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/annaviper/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/annaviper/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/annaviper/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/annaviper/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/annaviper/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/annaviper/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/annaviper/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/annaviper/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/annaviper/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/annaviper/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/annaviper/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/annaviper/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/annaviper/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/annaviper/lab-numpy/deployments',
#   'created_at': '2019-03-01T11:52:42Z',
#   'updated_at': '2019-03-01T11:52:44Z',
#   'pushed_at': '2019-02-27T18:28:41Z',
#   'git_url': 'git://github.com/annaviper/lab-numpy.git',
#   'ssh_url': 'git@github.com:annaviper/lab-numpy.git',
#   'clone_url': 'https://github.com/annaviper/lab-numpy.git',
#   'svn_url': 'https://github.com/annaviper/lab-numpy',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173293472,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyOTM0NzI=',
#   'name': 'lab-numpy',
#   'full_name': 'pausampietro/lab-numpy',
#   'private': False,
#   'owner': {'login': 'pausampietro',
#    'id': 46677967,
#    'node_id': 'MDQ6VXNlcjQ2Njc3OTY3',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/46677967?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pausampietro',
#    'html_url': 'https://github.com/pausampietro',
#    'followers_url': 'https://api.github.com/users/pausampietro/followers',
#    'following_url': 'https://api.github.com/users/pausampietro/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pausampietro/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pausampietro/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pausampietro/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pausampietro/orgs',
#    'repos_url': 'https://api.github.com/users/pausampietro/repos',
#    'events_url': 'https://api.github.com/users/pausampietro/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pausampietro/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/pausampietro/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/pausampietro/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/pausampietro/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/pausampietro/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/pausampietro/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/pausampietro/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/pausampietro/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/pausampietro/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/pausampietro/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/pausampietro/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/pausampietro/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/pausampietro/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/pausampietro/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/pausampietro/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/pausampietro/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/pausampietro/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/pausampietro/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/pausampietro/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/pausampietro/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/pausampietro/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/pausampietro/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/pausampietro/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/pausampietro/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/pausampietro/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/pausampietro/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/pausampietro/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/pausampietro/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/pausampietro/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/pausampietro/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/pausampietro/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/pausampietro/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/pausampietro/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/pausampietro/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/pausampietro/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/pausampietro/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/pausampietro/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/pausampietro/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/pausampietro/lab-numpy/deployments',
#   'created_at': '2019-03-01T11:48:26Z',
#   'updated_at': '2019-03-01T11:48:28Z',
#   'pushed_at': '2019-02-27T18:28:41Z',
#   'git_url': 'git://github.com/pausampietro/lab-numpy.git',
#   'ssh_url': 'git@github.com:pausampietro/lab-numpy.git',
#   'clone_url': 'https://github.com/pausampietro/lab-numpy.git',
#   'svn_url': 'https://github.com/pausampietro/lab-numpy',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173288842,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyODg4NDI=',
#   'name': 'lab-numpy',
#   'full_name': 'VilmaDaukantaite/lab-numpy',
#   'private': False,
#   'owner': {'login': 'VilmaDaukantaite',
#    'id': 47080875,
#    'node_id': 'MDQ6VXNlcjQ3MDgwODc1',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/47080875?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VilmaDaukantaite',
#    'html_url': 'https://github.com/VilmaDaukantaite',
#    'followers_url': 'https://api.github.com/users/VilmaDaukantaite/followers',
#    'following_url': 'https://api.github.com/users/VilmaDaukantaite/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/VilmaDaukantaite/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/VilmaDaukantaite/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/VilmaDaukantaite/subscriptions',
#    'organizations_url': 'https://api.github.com/users/VilmaDaukantaite/orgs',
#    'repos_url': 'https://api.github.com/users/VilmaDaukantaite/repos',
#    'events_url': 'https://api.github.com/users/VilmaDaukantaite/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/VilmaDaukantaite/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/VilmaDaukantaite/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/VilmaDaukantaite/lab-numpy/deployments',
#   'created_at': '2019-03-01T11:12:23Z',
#   'updated_at': '2019-03-01T14:51:21Z',
#   'pushed_at': '2019-03-01T14:51:20Z',
#   'git_url': 'git://github.com/VilmaDaukantaite/lab-numpy.git',
#   'ssh_url': 'git@github.com:VilmaDaukantaite/lab-numpy.git',
#   'clone_url': 'https://github.com/VilmaDaukantaite/lab-numpy.git',
#   'svn_url': 'https://github.com/VilmaDaukantaite/lab-numpy',
#   'homepage': None,
#   'size': 9,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173286839,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyODY4Mzk=',
#   'name': 'lab-numpy',
#   'full_name': 'roger-roig/lab-numpy',
#   'private': False,
#   'owner': {'login': 'roger-roig',
#    'id': 46109957,
#    'node_id': 'MDQ6VXNlcjQ2MTA5OTU3',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/46109957?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roger-roig',
#    'html_url': 'https://github.com/roger-roig',
#    'followers_url': 'https://api.github.com/users/roger-roig/followers',
#    'following_url': 'https://api.github.com/users/roger-roig/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/roger-roig/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/roger-roig/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/roger-roig/subscriptions',
#    'organizations_url': 'https://api.github.com/users/roger-roig/orgs',
#    'repos_url': 'https://api.github.com/users/roger-roig/repos',
#    'events_url': 'https://api.github.com/users/roger-roig/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/roger-roig/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/roger-roig/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/roger-roig/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/roger-roig/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/roger-roig/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/roger-roig/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/roger-roig/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/roger-roig/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/roger-roig/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/roger-roig/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/roger-roig/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/roger-roig/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/roger-roig/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/roger-roig/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/roger-roig/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/roger-roig/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/roger-roig/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/roger-roig/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/roger-roig/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/roger-roig/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/roger-roig/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/roger-roig/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/roger-roig/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/roger-roig/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/roger-roig/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/roger-roig/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/roger-roig/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/roger-roig/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/roger-roig/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/roger-roig/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/roger-roig/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/roger-roig/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/roger-roig/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/roger-roig/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/roger-roig/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/roger-roig/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/roger-roig/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/roger-roig/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/roger-roig/lab-numpy/deployments',
#   'created_at': '2019-03-01T10:57:11Z',
#   'updated_at': '2019-03-01T11:59:23Z',
#   'pushed_at': '2019-03-01T11:59:22Z',
#   'git_url': 'git://github.com/roger-roig/lab-numpy.git',
#   'ssh_url': 'git@github.com:roger-roig/lab-numpy.git',
#   'clone_url': 'https://github.com/roger-roig/lab-numpy.git',
#   'svn_url': 'https://github.com/roger-roig/lab-numpy',
#   'homepage': None,
#   'size': 9,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 173286692,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMyODY2OTI=',
#   'name': 'lab-numpy',
#   'full_name': 'jbe1992/lab-numpy',
#   'private': False,
#   'owner': {'login': 'jbe1992',
#    'id': 46814329,
#    'node_id': 'MDQ6VXNlcjQ2ODE0MzI5',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/46814329?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbe1992',
#    'html_url': 'https://github.com/jbe1992',
#    'followers_url': 'https://api.github.com/users/jbe1992/followers',
#    'following_url': 'https://api.github.com/users/jbe1992/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbe1992/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbe1992/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbe1992/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbe1992/orgs',
#    'repos_url': 'https://api.github.com/users/jbe1992/repos',
#    'events_url': 'https://api.github.com/users/jbe1992/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbe1992/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/jbe1992/lab-numpy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/jbe1992/lab-numpy',
#   'forks_url': 'https://api.github.com/repos/jbe1992/lab-numpy/forks',
#   'keys_url': 'https://api.github.com/repos/jbe1992/lab-numpy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/jbe1992/lab-numpy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/jbe1992/lab-numpy/teams',
#   'hooks_url': 'https://api.github.com/repos/jbe1992/lab-numpy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/jbe1992/lab-numpy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/jbe1992/lab-numpy/events',
#   'assignees_url': 'https://api.github.com/repos/jbe1992/lab-numpy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/jbe1992/lab-numpy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/jbe1992/lab-numpy/tags',
#   'blobs_url': 'https://api.github.com/repos/jbe1992/lab-numpy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jbe1992/lab-numpy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jbe1992/lab-numpy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/jbe1992/lab-numpy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/jbe1992/lab-numpy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/jbe1992/lab-numpy/languages',
#   'stargazers_url': 'https://api.github.com/repos/jbe1992/lab-numpy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/jbe1992/lab-numpy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/jbe1992/lab-numpy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jbe1992/lab-numpy/subscription',
#   'commits_url': 'https://api.github.com/repos/jbe1992/lab-numpy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/jbe1992/lab-numpy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/jbe1992/lab-numpy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/jbe1992/lab-numpy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/jbe1992/lab-numpy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/jbe1992/lab-numpy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/jbe1992/lab-numpy/merges',
#   'archive_url': 'https://api.github.com/repos/jbe1992/lab-numpy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/jbe1992/lab-numpy/downloads',
#   'issues_url': 'https://api.github.com/repos/jbe1992/lab-numpy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/jbe1992/lab-numpy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/jbe1992/lab-numpy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/jbe1992/lab-numpy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/jbe1992/lab-numpy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/jbe1992/lab-numpy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/jbe1992/lab-numpy/deployments',
#   'created_at': '2019-03-01T10:56:12Z',
#   'updated_at': '2019-03-01T13:49:44Z',
#   'pushed_at': '2019-03-01T13:49:43Z',
#   'git_url': 'git://github.com/jbe1992/lab-numpy.git',
#   'ssh_url': 'git@github.com:jbe1992/lab-numpy.git',
#   'clone_url': 'https://github.com/jbe1992/lab-numpy.git',
#   'svn_url': 'https://github.com/jbe1992/lab-numpy',
#   'homepage': None,
#   'size': 8,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
count = 0
for i in response:
    count += 1
print(count)
# Out:
# 12

# %%
language_array = [i['language'] for i in response]

# %%
language_array
# Out:
# ['Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']
